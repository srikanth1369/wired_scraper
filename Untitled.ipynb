# %%
import pandas as pd

# %%
pd.read_json('items.json')
# Out:
#              author                                              title  \
# 0       Dot Physics         Why Bigger Things Don’t Always Fall Faster
# 1       Dot Physics      Just How Hard Is Thor’s Battle Chain Workout?
# 2       Dot Physics  Can You Make a Hollow Metal Sphere So Big That...
# 3       Dot Physics  Is There an Optimal Driving Speed that Saves G...
# 4       Dot Physics  Can Your Gravitational Pull Affect Your Game o...
# 5   Smart Assistant  It’s Like GPT-3, but for Code—Fun, Fast, and F...
# 6       Dot Physics  Why Buzz Lightyear’s Rocket Launch Looks Bette...
# 7       Dot Physics  If Clouds Are Made of Water, How Do They Stay ...
# 8        Say Again?  ’s Code-Writing AI Points to the Future of Com...
# 9       Dot Physics  How to Prepare for the Robot Apocalypse (If Yo...
# 10           Movies               Imagines an Optimistic Future for AI
# 11            Ideas           A Field Guide for Nature-Resistant Nerds
# ...
